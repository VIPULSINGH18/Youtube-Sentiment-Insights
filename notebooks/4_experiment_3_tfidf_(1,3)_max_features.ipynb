# %% [markdown]
# # How many max features?

# %%
# !pip install mlflow boto3
# Out:
# Requirement already satisfied: mlflow in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (2.17.0)
# Requirement already satisfied: boto3 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (1.35.36)
# Requirement already satisfied: mlflow-skinny==2.17.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (2.17.0)
# Requirement already satisfied: Flask<4 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (1.18.4)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (3.10.2)
# Requirement already satisfied: matplotlib<4 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: numpy<3 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (2.1.2)
# Requirement already satisfied: pandas<3 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (1.17.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (2.0.48)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: waitress<4 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (0.102.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (1.40.0)
# Requirement already satisfied: packaging<25 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (5.29.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (0.5.5)
# Requirement already satisfied: botocore<1.36.0,>=1.35.36 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from boto3) (1.35.99)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from boto3) (0.10.4)
# Requirement already satisfied: Mako in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from botocore<1.36.0,>=1.35.36->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from botocore<1.36.0,>=1.35.36->boto3) (2.6.3)
# Requirement already satisfied: pywin32>=304 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from Flask<4->mlflow) (3.1.7)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from graphene<4->mlflow) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from matplotlib<4->mlflow) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from matplotlib<4->mlflow) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from matplotlib<4->mlflow) (12.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from pandas<3->mlflow) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.2)
# Requirement already satisfied: colorama in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.17.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.49.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.0->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (0.61b0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.36->boto3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.6.3)
# Requirement already satisfied: pycparser in c:\users\hp\onedrive\desktop\mlops\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (3.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# AWS Access Key ID [None]: AKIAUTCYOPXTOB5BVMGZ
# AWS Secret Access Key [None]: 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
# Default region name [None]: us-east-1
# Default output format [None]:

# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 3 - TfIdf Trigram max_features")
# Out:
# 2026/03/28 23:36:06 INFO mlflow.tracking.fluent: Experiment with name 'Exp 3 - TfIdf Trigram max_features' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlflow-buckets-18/4', creation_time=1774721166734, experiment_id='4', last_update_time=1774721166734, lifecycle_stage='active', name='Exp 3 - TfIdf Trigram max_features', tags={}>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
df = pd.read_csv('my_reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Function to run the experiment
def run_experiment_tfidf_max_features(max_features):
    ngram_range = (1, 3)  # Trigram setting

    # Step 2: Vectorization using TF-IDF with varying max_features
    vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)

    X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

    X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)

    # Step 4: Define and train a Random Forest model
    with mlflow.start_run() as run:
        # Set tags for the experiment and run
        mlflow.set_tag("mlflow.runName", f"TFIDF_Trigrams_max_features_{max_features}")
        mlflow.set_tag("experiment_type", "feature_engineering")
        mlflow.set_tag("model_type", "RandomForestClassifier")

        # Add a description
        mlflow.set_tag("description", f"RandomForest with TF-IDF Trigrams, max_features={max_features}")

        # Log vectorizer parameters
        mlflow.log_param("vectorizer_type", "TF-IDF")
        mlflow.log_param("ngram_range", ngram_range)
        mlflow.log_param("vectorizer_max_features", max_features)

        # Log Random Forest parameters
        n_estimators = 200
        max_depth = 15

        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)

        # Initialize and train the model
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        model.fit(X_train, y_train)

        # Step 5: Make predictions and log metrics
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix: TF-IDF Trigrams, max_features={max_features}")
        plt.savefig("confusion_matrix_3.png")
        mlflow.log_artifact("confusion_matrix_3.png")
        plt.close()

        # Log the model
        mlflow.sklearn.log_model(model, f"random_forest_model_tfidf_trigrams_{max_features}")

# Step 6: Test various max_features values
max_features_values = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]

for max_features in max_features_values:
    run_experiment_tfidf_max_features(max_features)
# Out:
# 2026/03/28 23:47:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:48:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_1000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/ddbc3e4383b04d6d8e214ec0e660a6fb.
# 2026/03/28 23:48:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:48:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:49:25 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_2000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/f39bec6a50cc4318b87f1edb10d23c98.
# 2026/03/28 23:49:25 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:49:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:50:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_3000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/14c7a685eb81444a94fc8def4a492a73.
# 2026/03/28 23:50:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:51:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:51:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_4000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/0cf3659ee7784304b6204cdd211f8820.
# 2026/03/28 23:51:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:51:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:52:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_5000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/21ba73213cc3499b9fef33983d792b3b.
# 2026/03/28 23:52:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:52:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:53:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_6000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/e0bca78ccd3a4f0f8adfc644894e11b2.
# 2026/03/28 23:53:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:53:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:53:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_7000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/cb933b00a13547ccbf27238981e2cdaa.
# 2026/03/28 23:53:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:54:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:54:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_8000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/44255a3ea2394dc9bcd196c8bf8dc49e.
# 2026/03/28 23:54:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:55:14 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:55:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_9000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/86cef782a0904833bf44e92da062f8fe.
# 2026/03/28 23:55:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
# 2026/03/28 23:56:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/03/28 23:56:41 INFO mlflow.tracking._tracking_service.client: 🏃 View run TFIDF_Trigrams_max_features_10000 at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4/runs/0292b6d65d224bbeaea572d1ef6dff94.
# 2026/03/28 23:56:41 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-13-201-86-39.ap-south-1.compute.amazonaws.com:5000/#/experiments/4.
